# %% [markdown]
# ## 7. Sorteo de amigo invisible

# %% [markdown]
# ### Enunciado:

# %% [markdown]
# Solicite al usuario una lista de nombres de participantes (separados por coma). El programa debe asignar aleatoriamente a cada persona un amigo invisible, cumpliendo que **nadie se tenga a sí mismo**.

# %% [markdown]
# Validaciones:
# - Debe haber al menos 3 participantes.
# - No debe haber nombres duplicados (comparar ignorando mayúsculas y espacios extra).

# %% [markdown]
# ### Ejemplo de entrada y salida esperada:

# %% [raw]
# Ingrese los participantes (separados por coma): Ana, Pedro, Lucía, Mateo, Sofía
#
# Sorteo de amigo invisible:
#   Ana → Mateo
#   Pedro → Sofía
#   Lucía → Ana
#   Mateo → Pedro
#   Sofía → Lucía

# %% [markdown]
# **Nota:** Los resultados varían en cada ejecución por ser aleatorios,
# pero ninguna persona debe tenerse a sí misma.

# %% [markdown]
# ### Resolución:

# %%
import sys
sys.path.append("../src")

from ejercicio_07 import print_invisible_friends
print_invisible_friends()
# Out:
# No se ingresaron participantes.
